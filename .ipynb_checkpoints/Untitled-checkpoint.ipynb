# %% [markdown]
# # Preprocesamiento

# %% [markdown]
# ## importar librerias

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## lectura de datos

# %%
df = pd.read_csv('./in/multiple_choice_responses.csv',low_memory=False)
df.head()
# Out:
#   Time from Start to Finish (seconds)                           Q1  \
# 0               Duration (in seconds)  What is your age (# years)?
# 1                                 510                        22-24
# 2                                 423                        40-44
# 3                                  83                        55-59
# 4                                 391                        40-44
#
#                                        Q2  \
# 0  What is your gender? - Selected Choice
# 1                                    Male
# 2                                    Male
# 3                                  Female
# 4                                    Male
#
#                                        Q2_OTHER_TEXT  \
# 0  What is your gender? - Prefer to self-describe...
# 1                                                 -1
# 2                                                 -1
# 3                                                 -1
# ...

# %% [markdown]
# ## Limpieza de datos

# %% [markdown]
# ### Eliminando valores atípicos en cuestiones de tiempo
